# %% [markdown]
# ## Pre-processing output for 'looking' project
# - Given that the original source code does not support numerical predictions as an output file (e.g. csv file), I added an alternate method in the
# predictor class that collects the predictions into a csv file and creates it in the output folder.
# - Below is a demo of how I would run the script locally.
# - Note that running the model takes a lot of time, especially if your local machine is not CUDA compatible. I suggest running the model in a server
# that satisfy such requirement.

# %%
import sys
import os
os.chdir('../4. Eye Contact Detection/looking')

# %%
import openpifpaf
import torch
import torchvision
print(openpifpaf.__version__)
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 0.13.11
# 1.13.1
# 0.14.1

# %%
# !{sys.executable} 'predict_alt.py' --images '../../run-models/data/dummy/' --glob 'jpg'
# Out:
# OpenPifPaf version 0.13.11
# PyTorch version 1.13.1
# device : cpu
# shufflenetv2k30
# cpu
# 0it [00:00, ?it/s]src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# 1it [00:02,  2.07s/it]
# 0it [00:00, ?it/s]src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# 1it [00:06,  6.63s/it]
# 1it [00:01,  1.87s/it]
# 1it [00:02,  2.78s/it]
# 1it [00:03,  3.74s/it]
# 1it [00:04,  4.08s/it]
# 1it [00:02,  2.33s/it]
# 1it [00:02,  2.14s/it]
# 1it [00:05,  5.79s/it]
# 1it [00:01,  1.90s/it]
# 1it [00:03,  3.89s/it]
# 1it [00:02,  2.14s/it]
# 0it [00:00, ?it/s]src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# 1it [00:06,  6.39s/it]
# 1it [00:06,  6.12s/it]
# 1it [00:04,  4.05s/it]
# ...
